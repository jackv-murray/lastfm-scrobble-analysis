# %%
import requests
from datetime import date, datetime, timedelta
from dotenv import load_dotenv
import os
import pandas as pd
import time

load_dotenv()
# Out:
# True

# %%
def get_lastfm_scrobbles(api_key, username, from_timestamp, to_timestamp, page=1):
    base_url = "http://ws.audioscrobbler.com/2.0/"
    params = {
        'method': 'user.getrecenttracks',
        'user': username,
        'api_key': api_key,
        'limit': 20,
        'from': from_timestamp,
        'to': to_timestamp,
        'format': 'json',
        'page': page  # Add the page parameter
    }

    response = requests.get(base_url, params=params)
    data = response.json()

    if 'error' in data:
        print(f"Error: {data['message']}")
        return None

    scrobbles = data['recenttracks']['track']
    return scrobbles

# %%
def get_artist_top_tag(api_key, artist):
    base_url = "http://ws.audioscrobbler.com/2.0/"
    params = {
        'method': 'artist.getTopTags',
        'artist': artist,
        'api_key': api_key,
        'format': 'json'
    }

    response = requests.get(base_url, params=params)
    data = response.json()

    if 'error' in data:
        print(f"Error: {data['message']}")
        return None

    tags = [tag['name'] for tag in data.get('toptags', {}).get('tag', [])]
    top_tag = tags[0] if tags else 'N/A'
    return top_tag

# %%
def organize_scrobbles(scrobbles, api_key):
    timestamp_list = []
    artist_list = []
    track_list = []
    top_tag_list = []

    for scrobble in scrobbles:
        timestamp = scrobble.get('date', {}).get('uts', 'N/A')
        
        if timestamp != 'N/A':
            timestamp = datetime.utcfromtimestamp(int(timestamp)).strftime('%Y-%m-%d %H:%M:%S')

        artist = scrobble['artist']['#text']
        track = scrobble['name']
        tags = get_artist_top_tag(api_key, artist) if artist else None
        

        timestamp_list.append(timestamp)
        artist_list.append(artist)
        track_list.append(track)
        top_tag_list.append(tags)

    return timestamp_list, artist_list, track_list, top_tag_list

# %%
def create_dataframe(timestamps, artists, tracks, tags):
    data = {'Timestamp': timestamps, 'Artist': artists, 'Track': tracks, 'Top Tags': tags}
    df = pd.DataFrame(data)
    return df

# %%
def main():
    api_key = os.getenv('API_KEY')
    username = 'sorfildor'

    # Get timestamps for the previous day
    today = datetime.now()
    yesterday = today - timedelta(days=1)
    from_timestamp = int(yesterday.replace(hour=0, minute=0, second=0, microsecond=0).timestamp())
    to_timestamp = int(yesterday.replace(hour=23, minute=59, second=59, microsecond=999999).timestamp())

    all_scrobbles = []
    page = 1

    while True:
        start_time = time.time()
        scrobbles = get_lastfm_scrobbles(api_key, username, from_timestamp, to_timestamp, page)
        
        if not scrobbles:
            break  # No more pages or an error occurred

        all_scrobbles.extend(scrobbles)

        # Check if the number of returned scrobbles is less than the limit
        if len(scrobbles) < 20:
            print(f"Page {page}: {len(scrobbles)} records, Time: {time.time() - start_time:.2f} seconds")
            break 


        print(f"Page {page}: {len(scrobbles)} records, Time: {time.time() - start_time:.2f} seconds")
        page += 1

    if all_scrobbles:
        timestamps, artists, tracks, tags = organize_scrobbles(all_scrobbles, api_key)
        df = create_dataframe(timestamps, artists, tracks, tags)

        # Returns the df minus any entries with a Timestamp as 'N/A'
        # This is due to tracks being currently listened to appearing as such
        print(f"Total scrobbles for {yesterday.date()} is {len(df)}")
        return df[df['Timestamp'] != 'N/A']

if __name__ == "__main__":
    result_df = main()
# Out:
# Page 1: 21 records, Time: 0.47 seconds
# Page 2: 21 records, Time: 0.97 seconds
# Page 3: 14 records, Time: 1.31 seconds
# total scrobbles for 2024-02-08 is 56

# %%
result_df
# Out:
#               Timestamp                  Artist  \
# 1   2024-02-08 18:08:27                Kingcrow
# 2   2024-02-08 18:08:27                Kingcrow
# 3   2024-02-08 18:03:12                Kingcrow
# 4   2024-02-08 17:57:37                Kingcrow
# 5   2024-02-08 17:51:20                Kingcrow
# 6   2024-02-08 17:46:26                Kingcrow
# 7   2024-02-08 17:42:05                Kingcrow
# 8   2024-02-08 17:27:16              Andrew Odd
# 9   2024-02-08 17:23:39       Desolate Horizons
# 10  2024-02-08 17:17:14  Carbon Based Lifeforms
# 11  2024-02-08 17:12:38            Sundial Aeon
# 12  2024-02-08 17:07:17            Solar Fields
# 13  2024-02-08 17:02:44                  Abakus
# 14  2024-02-08 16:58:42            Indian Wells
# 15  2024-02-08 16:56:05       Desolate Horizons
# 16  2024-02-08 16:51:09  Carbon Based Lifeforms
# 17  2024-02-08 16:48:29                Hinkstep
# 18  2024-02-08 16:44:24         Abstract Aprils
# 19  2024-02-08 16:42:32                  Kodomo
# 20  2024-02-08 16:40:03                Jupi/ter
# 22  2024-02-08 16:37:36                    Gcom
# 23  2024-02-08 16:32:41  Carbon Based Lifeforms
# 24  2024-02-08 16:24:19  Carbon Based Lifeforms
# 25  2024-02-08 16:10:44  Carbon Based Lifeforms
# 26  2024-02-08 16:03:11  Carbon Based Lifeforms
# 27  2024-02-08 15:56:39  Carbon Based Lifeforms
# 28  2024-02-08 15:50:47         Ozric Tentacles
# 29  2024-02-08 15:45:11         Ozric Tentacles
# 30  2024-02-08 15:39:56         Ozric Tentacles
# 31  2024-02-08 14:54:59         Ozric Tentacles
# 32  2024-02-08 14:50:08         Ozric Tentacles
# 33  2024-02-08 14:40:26         Ozric Tentacles
# 34  2024-02-08 14:35:05         Ozric Tentacles
# 35  2024-02-08 14:16:40               Deathprod
# 36  2024-02-08 14:12:09                   Raime
# 37  2024-02-08 14:04:53       Caterina Barbieri
# 38  2024-02-08 14:01:29         Body Sculptures
# 39  2024-02-08 13:59:03         Augustus Muller
# 40  2024-02-08 13:54:03              Orphan Ann
# 41  2024-02-08 12:01:26                   Raime
# 43  2024-02-08 10:31:42                   Raime
# 44  2024-02-08 10:24:15                   Raime
# 45  2024-02-08 10:22:17           Forest Swords
# 46  2024-02-08 10:17:45           Forest Swords
# 47  2024-02-08 10:14:20           Forest Swords
# 48  2024-02-08 10:08:04           Forest Swords
# 49  2024-02-08 10:04:53           Forest Swords
# 50  2024-02-08 10:01:11           Forest Swords
# 51  2024-02-08 09:57:32           Forest Swords
# 52  2024-02-08 09:55:59           Forest Swords
# 53  2024-02-08 09:51:27           Forest Swords
# 54  2024-02-08 09:48:02           Forest Swords
# 55  2024-02-08 09:26:03           Forest Swords
#
#                                                 Track           Top Tags
# 1                                Fading Out (Part IV)  Progressive metal
# 2                                              Closer  Progressive metal
# 3                                              Closer  Progressive metal
# 4                                            Drenched  Progressive metal
# 5                                              Adrift  Progressive metal
# 6                                  Night's Descending  Progressive metal
# 7                                            The Moth  Progressive metal
# 8                                           Cosmogony            ambient
# 9                                            Pristine            ambient
# 10                                         Flytta Dig            ambient
# 11                                              Spore            ambient
# 12                     Bridge wide open (Origin 2013)            ambient
# 13                                         Evolutions            ambient
# 14                                    Night Arp Blues            ambient
# 15    Everyday, There Is That Memory or That Daydream            ambient
# 16                          Transmission/Intermission            ambient
# 17                                       A Generation          downtempo
# 18                                             Radius            ambient
# 19                                 Disappearing Light                idm
# 20                                              Clore            ambient
# 22                                       Helix Nebula         electronic
# 23                                               ~42°            ambient
# 24                                 Finite State Space            ambient
# 25                                        Eigenvector            ambient
# 26                                    Sphere Eversion            ambient
# 27                                            Delsjön            ambient
# 28                                      Eternal Wheel   Progressive rock
# 29                                           Myriapod   Progressive rock
# 30                                 Dance Of The Loomi   Progressive rock
# 31                                          Al-Salooq   Progressive rock
# 32                                       Arborescence   Progressive rock
# 33                                         Yog-Bar-Og   Progressive rock
# 34                                       Astro Cortex   Progressive rock
# 35                               Dead People's Things       dark ambient
# 36                                  Passed Over Trail            ambient
# 37                     Fantas for Saxophone and Voice         electronic
# 38  A Collection of Ceramic Vases (Yves Saint Laur...         industrial
# 39                              Stretching / Invading      minimal synth
# 40                                     Vi är överallt            ambient
# 41                                            Stammer            ambient
# 43                                   The Last Foundry            ambient
# 44                                  Passed Over Trail            ambient
# 45                                                Tar       experimental
# 46                                              Caged       experimental
# 47                                    Night Sculpture       experimental
# 48                                                End       experimental
# 49                                              Hjope       experimental
# 50                                         Chain Link       experimental
# 51                                            The Low       experimental
# 52                                                Tar       experimental
# 53                                              Caged       experimental
# 54                                    Night Sculpture       experimental
# 55                                    Night Sculpture       experimental
